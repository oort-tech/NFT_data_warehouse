# %%
import requests
import json
# Pull the top-selling contract / top-selling contract sale stat / metadata for all the time

page_size = 50

url_top_contract = 'https://api.nftport.xyz/v0/contracts/top?page_size='+str(page_size)+'&period=all&order_by=volume&chain=ethereum&chain=polygon'

file_stat = 'contract_stat.json'
file_contract = 'top_contract.json'
file_meta = 'meta.json'




g = open(file_stat, 'w')
h = open(file_contract, 'w')
k = open(file_meta, 'w')


headers = {
    "accept": "application/json",
    "Authorization": "ffe648a9-5167-4be1-a826-e7e8e482dcc7"
}


response_top = requests.get(url_top_contract, headers=headers)
con_add = []
print(count, 'top contract success')
top_contract = json.loads(response_top.text)
address = top_contract['contracts']
for data in address:    
    con_add.append(data['contract_address'])
json.dump(top_contract, h, indent = 4)
for i in range(50):
    url_stat = 'https://api.nftport.xyz/v0/transactions/stats/{}?chain=ethereum'.format(con_add[i])
    print(url_stat)
    print(i)
    response_stat = requests.get(url_stat, headers=headers)
    contract_stat = json.loads(response_stat.text)
    json.dump(contract_stat, g, indent = 4)
    time.sleep(0.5)
    
for j in range(50):
    url_meta = 'https://api.nftport.xyz/v0/nfts/{}?chain=ethereum&page_number=1&page_size=50&include=metadata&refresh_metadata=false'.format(con_add[j])
    print(url_meta)
    print(j)
    response_meta = requests.get(url_meta, headers=headers)
    meta = json.loads(response_meta.text)
    json.dump(meta, k, indent = 4)
    time.sleep(0.5)
# Out:
# 0 top contract success
# https://api.nftport.xyz/v0/transactions/stats/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d?chain=ethereum
# 0
# https://api.nftport.xyz/v0/transactions/stats/0x60e4d786628fea6478f785a6d7e704777c86a7c6?chain=ethereum
# 1
# https://api.nftport.xyz/v0/transactions/stats/0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258?chain=ethereum
# 2
# https://api.nftport.xyz/v0/transactions/stats/0xed5af388653567af2f388e6224dc7c4b3241c544?chain=ethereum
# 3
# https://api.nftport.xyz/v0/transactions/stats/0x99a9b7c1116f9ceeb1652de04d5969cce509b069?chain=ethereum
# 4
# https://api.nftport.xyz/v0/transactions/stats/0xa7d8d9ef8d8ce8992df33d8b8cf4aebabd5bd270?chain=ethereum
# 5
# https://api.nftport.xyz/v0/transactions/stats/0x059edd72cd353df5106d2b9cc5ab83a52287ac3a?chain=ethereum
# 6
# https://api.nftport.xyz/v0/transactions/stats/0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b?chain=ethereum
# 7
# ...

# %%
import requests
import json
# Pull the top-selling contract / top-selling contract sale stat / metadata for LAST 24 hours

time = 24h       #7d or 30d or all
page_size = 50

url_top_contract = 'https://api.nftport.xyz/v0/contracts/top?page_size='+str(page_size)+'&period={}&order_by=volume&chain=ethereum&chain=polygon'.format(time)

file_stat = 'contract_stat_24h.json'
file_contract = 'top_contract_24h.json'
file_meta = 'meta_24h.json'




g = open(file_stat, 'w')
h = open(file_contract, 'w')
k = open(file_meta, 'w')


headers = {
    "accept": "application/json",
    "Authorization": "ffe648a9-5167-4be1-a826-e7e8e482dcc7"
}


response_top = requests.get(url_top_contract, headers=headers)
con_add = []
print(count, 'top contract success')
top_contract = json.loads(response_top.text)
address = top_contract['contracts']
for data in address:    
    con_add.append(data['contract_address'])
json.dump(top_contract, h, indent = 4)
for i in range(50):
    url_stat = 'https://api.nftport.xyz/v0/transactions/stats/{}?chain=ethereum'.format(con_add[i])
    print(url_stat)
    print(i)
    response_stat = requests.get(url_stat, headers=headers)
    contract_stat = json.loads(response_stat.text)
    json.dump(contract_stat, g, indent = 4)
    time.sleep(0.5)
    
for j in range(50):
    url_meta = 'https://api.nftport.xyz/v0/nfts/{}?chain=ethereum&page_number=1&page_size=50&include=metadata&refresh_metadata=false'.format(con_add[j])
    print(url_meta)
    print(j)
    response_meta = requests.get(url_meta, headers=headers)
    meta = json.loads(response_meta.text)
    json.dump(meta, k, indent = 4)
    time.sleep(0.5)
# Out:
# 0 top contract success
# https://api.nftport.xyz/v0/transactions/stats/0xed5af388653567af2f388e6224dc7c4b3241c544?chain=ethereum
# 0
# https://api.nftport.xyz/v0/transactions/stats/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d?chain=ethereum
# 1
# https://api.nftport.xyz/v0/transactions/stats/0xb7f7f6c52f2e2fdb1963eab30438024864c313f6?chain=ethereum
# 2
# https://api.nftport.xyz/v0/transactions/stats/0x60e4d786628fea6478f785a6d7e704777c86a7c6?chain=ethereum
# 3
# https://api.nftport.xyz/v0/transactions/stats/0x8821bee2ba0df28761afff119d66390d594cd280?chain=ethereum
# 4
# https://api.nftport.xyz/v0/transactions/stats/0x5af0d9827e0c53e4799bb226655a1de152a425a5?chain=ethereum
# 5
# https://api.nftport.xyz/v0/transactions/stats/0xbd3531da5cf5857e7cfaa92426877b022e612cf8?chain=ethereum
# 6
# https://api.nftport.xyz/v0/transactions/stats/0x4b15a9c28034dc83db40cd810001427d3bd7163d?chain=ethereum
# 7
# ...

# %%
import requests
import json

# Pull the top-selling contract / top-selling contract sale stat / metadata for LAST 7 days


page_size = 50

url_top_contract = 'https://api.nftport.xyz/v0/contracts/top?page_size='+str(page_size)+'&period=7d&order_by=volume&chain=ethereum&chain=polygon'

file_stat = 'contract_stat_7d.json'
file_contract = 'top_contract_7d.json'
file_meta = 'meta_7d.json'




g = open(file_stat, 'w')
h = open(file_contract, 'w')
k = open(file_meta, 'w')


headers = {
    "accept": "application/json",
    "Authorization": "ffe648a9-5167-4be1-a826-e7e8e482dcc7"
}


response_top = requests.get(url_top_contract, headers=headers)
con_add = []
print(count, 'top contract success')
top_contract = json.loads(response_top.text)
address = top_contract['contracts']
for data in address:    
    con_add.append(data['contract_address'])
json.dump(top_contract, h, indent = 4)
for i in range(50):
    url_stat = 'https://api.nftport.xyz/v0/transactions/stats/{}?chain=ethereum'.format(con_add[i])
    print(url_stat)
    print(i)
    response_stat = requests.get(url_stat, headers=headers)
    contract_stat = json.loads(response_stat.text)
    json.dump(contract_stat, g, indent = 4)
    time.sleep(0.5)
    
for j in range(50):
    url_meta = 'https://api.nftport.xyz/v0/nfts/{}?chain=ethereum&page_number=1&page_size=50&include=metadata&refresh_metadata=false'.format(con_add[j])
    print(url_meta)
    print(j)
    response_meta = requests.get(url_meta, headers=headers)
    meta = json.loads(response_meta.text)
    json.dump(meta, k, indent = 4)
    time.sleep(0.5)
# Out:
# 0 top contract success
# https://api.nftport.xyz/v0/transactions/stats/0x60e4d786628fea6478f785a6d7e704777c86a7c6?chain=ethereum
# 0
# https://api.nftport.xyz/v0/transactions/stats/0xed5af388653567af2f388e6224dc7c4b3241c544?chain=ethereum
# 1
# https://api.nftport.xyz/v0/transactions/stats/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d?chain=ethereum
# 2
# https://api.nftport.xyz/v0/transactions/stats/0xb7f7f6c52f2e2fdb1963eab30438024864c313f6?chain=ethereum
# 3
# https://api.nftport.xyz/v0/transactions/stats/0x5af0d9827e0c53e4799bb226655a1de152a425a5?chain=ethereum
# 4
# https://api.nftport.xyz/v0/transactions/stats/0x769272677fab02575e84945f03eca517acc544cc?chain=ethereum
# 5
# https://api.nftport.xyz/v0/transactions/stats/0x8821bee2ba0df28761afff119d66390d594cd280?chain=ethereum
# 6
# https://api.nftport.xyz/v0/transactions/stats/0x8a90cab2b38dba80c64b7734e58ee1db38b8992e?chain=ethereum
# 7
# ...

# %%
import requests
import json

# Pull the top-selling contract / top-selling contract sale stat / metadata for LAST 30 days

page_size = 50

url_top_contract = 'https://api.nftport.xyz/v0/contracts/top?page_size='+str(page_size)+'&period=30d&order_by=volume&chain=ethereum&chain=polygon'

file_stat = 'contract_stat_30d.json'
file_contract = 'top_contract_30d.json'
file_meta = 'meta_30d.json'




g = open(file_stat, 'w')
h = open(file_contract, 'w')
k = open(file_meta, 'w')


headers = {
    "accept": "application/json",
    "Authorization": "ffe648a9-5167-4be1-a826-e7e8e482dcc7"
}


response_top = requests.get(url_top_contract, headers=headers)
con_add = []
print(count, 'top contract success')
top_contract = json.loads(response_top.text)
address = top_contract['contracts']
for data in address:    
    con_add.append(data['contract_address'])
json.dump(top_contract, h, indent = 4)
for i in range(50):
    url_stat = 'https://api.nftport.xyz/v0/transactions/stats/{}?chain=ethereum'.format(con_add[i])
    print(url_stat)
    print(i)
    response_stat = requests.get(url_stat, headers=headers)
    contract_stat = json.loads(response_stat.text)
    json.dump(contract_stat, g, indent = 4)
    time.sleep(0.5)
    
for j in range(50):
    url_meta = 'https://api.nftport.xyz/v0/nfts/{}?chain=ethereum&page_number=1&page_size=50&include=metadata&refresh_metadata=false'.format(con_add[j])
    print(url_meta)
    print(j)
    response_meta = requests.get(url_meta, headers=headers)
    meta = json.loads(response_meta.text)
    json.dump(meta, k, indent = 4)
    time.sleep(0.5)
# Out:
# 0 top contract success
# https://api.nftport.xyz/v0/transactions/stats/0xb7f7f6c52f2e2fdb1963eab30438024864c313f6?chain=ethereum
# 0
# https://api.nftport.xyz/v0/transactions/stats/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d?chain=ethereum
# 1
# https://api.nftport.xyz/v0/transactions/stats/0x60e4d786628fea6478f785a6d7e704777c86a7c6?chain=ethereum
# 2
# https://api.nftport.xyz/v0/transactions/stats/0xed5af388653567af2f388e6224dc7c4b3241c544?chain=ethereum
# 3
# https://api.nftport.xyz/v0/transactions/stats/0xd774557b647330c91bf44cfeab205095f7e6c367?chain=ethereum
# 4
# https://api.nftport.xyz/v0/transactions/stats/0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258?chain=ethereum
# 5
# https://api.nftport.xyz/v0/transactions/stats/0x306b1ea3ecdf94ab739f1910bbda052ed4a9f949?chain=ethereum
# 6
# https://api.nftport.xyz/v0/transactions/stats/0x4b15a9c28034dc83db40cd810001427d3bd7163d?chain=ethereum
# 7
# ...
